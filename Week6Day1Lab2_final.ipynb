# %% [markdown]
# This dataset can contain songs of your choice, others collected from the web or any other combination. Some sources of songs can be:

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/unpopular_songs.csv')
data.head(20)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.530   0.770    4    -6.633     0       0.0389       0.28400
# 1          0.565   0.730    1    -6.063     1       0.0730       0.36500
# 2          0.427   0.546    4    -8.727     1       0.0849       0.53900
# 3          0.421   0.531    7    -5.516     1       0.0262       0.70600
# 4          0.537   0.804    8    -7.378     0       0.1570       0.37900
# 5          0.710   0.621    9    -7.879     0       0.0329       0.40500
# 6          0.419   0.821   11    -5.768     0       0.0431       0.01370
# 7          0.565   0.624    1    -5.718     1       0.0351       0.00442
# 8          0.547   0.560    0    -7.187     1       0.0510       0.55100
# 9          0.533   0.785    5    -5.466     1       0.0481       0.59100
# 10         0.482   0.369    2    -7.637     0       0.0412       0.75000
# 11         0.589   0.659    2    -7.491     1       0.0516       0.10400
# ...

# %%
data.shape
# Out:
# (10877, 17)

# %%
data.drop_duplicates()
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.530  0.7700    4    -6.633     0       0.0389         0.284
# 1             0.565  0.7300    1    -6.063     1       0.0730         0.365
# 2             0.427  0.5460    4    -8.727     1       0.0849         0.539
# 3             0.421  0.5310    7    -5.516     1       0.0262         0.706
# 4             0.537  0.8040    8    -7.378     0       0.1570         0.379
# ...             ...     ...  ...       ...   ...          ...           ...
# 10872         0.686  0.1320    0   -20.363     1       0.0339         0.268
# 10873         0.532  0.0573   11   -20.476     0       0.0479         0.900
# 10874         0.589  0.0308    3   -27.237     1       0.0405         0.943
# 10875         0.669  0.0381    7   -18.631     1       0.0382         0.783
# 10876         0.818  0.1460    9   -19.684     0       0.1230         0.828
#
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data = data[['track_name', 'track_artist']]
data
# Out:
#                track_name        track_artist
# 0              No Regrets        James Reeder
# 1               Wild Life        James Reeder
# 2                   Fangs        James Reeder
# 3             Afterburner        James Reeder
# 4         Hellfire Rising        James Reeder
# ...                   ...                 ...
# 10872         Bugs n Toes  Good Girl, Bad Boy
# 10873  Scattered Thoughts  Good Girl, Bad Boy
# 10874        Travelin Bug  Good Girl, Bad Boy
# 10875           Goodnight  Good Girl, Bad Boy
# 10876            Paranoid         Talen Talea
#
# [10877 rows x 2 columns]

# %%
data = data[data.index < 2500]
data.shape
# Out:
# (2500, 2)

# %%
data2 = pd.read_csv('data/hotsongs.csv')
data2.head(20)
# Out:
#                             title                               artist
# 0                       Anti-Hero                         Taylor Swift
# 1                   Lavender Haze                         Taylor Swift
# 2                          Maroon                         Taylor Swift
# 3               Snow On The Beach  Taylor Swift Featuring Lana Del Rey
# 4                   Midnight Rain                         Taylor Swift
# 5                       Bejeweled                         Taylor Swift
# 6                    Question...?                         Taylor Swift
# 7         You're On Your Own, Kid                         Taylor Swift
# 8                           Karma                         Taylor Swift
# 9                  Vigilante Shit                         Taylor Swift
# 10                         Unholy               Sam Smith & Kim Petras
# 11                      Bad Habit                           Steve Lacy
# ...

# %%
data2 = data2.rename(columns = {'title':'track_name', 'artist':'track_artist'})

# %%
merge_data = pd.concat([data, data2], axis=0)
merge_data
# Out:
#          track_name                track_artist
# 0        No Regrets                James Reeder
# 1         Wild Life                James Reeder
# 2             Fangs                James Reeder
# 3       Afterburner                James Reeder
# 4   Hellfire Rising                James Reeder
# ..              ...                         ...
# 95         Dark Red                  Steve Lacy
# 96      From Now On   Lil Baby Featuring Future
# 97        Forget Me               Lewis Capaldi
# 98         Miss You  Oliver Tree & Robin Schulz
# 99         Despecha                     Rosalia
#
# [2600 rows x 2 columns]

# %%
merge_data.duplicated().value_counts()
# Out:
# False    2597
# True        3
# dtype: int64

# %%
merge_data.tail(100)
# Out:
#            track_name                         track_artist
# 0           Anti-Hero                         Taylor Swift
# 1       Lavender Haze                         Taylor Swift
# 2              Maroon                         Taylor Swift
# 3   Snow On The Beach  Taylor Swift Featuring Lana Del Rey
# 4       Midnight Rain                         Taylor Swift
# ..                ...                                  ...
# 95           Dark Red                           Steve Lacy
# 96        From Now On            Lil Baby Featuring Future
# 97          Forget Me                        Lewis Capaldi
# 98           Miss You           Oliver Tree & Robin Schulz
# 99           Despecha                              Rosalia
#
# [100 rows x 2 columns]

# %%
merge_data = merge_data.drop_duplicates()

# %%
merge_data.shape
# Out:
# (2597, 2)

# %%
merge_data.tail(100)
# Out:
#            track_name                         track_artist
# 0           Anti-Hero                         Taylor Swift
# 1       Lavender Haze                         Taylor Swift
# 2              Maroon                         Taylor Swift
# 3   Snow On The Beach  Taylor Swift Featuring Lana Del Rey
# 4       Midnight Rain                         Taylor Swift
# ..                ...                                  ...
# 95           Dark Red                           Steve Lacy
# 96        From Now On            Lil Baby Featuring Future
# 97          Forget Me                        Lewis Capaldi
# 98           Miss You           Oliver Tree & Robin Schulz
# 99           Despecha                              Rosalia
#
# [100 rows x 2 columns]

# %%
merge_data = merge_data.iloc[:2497,:]

# %%
merge_data.tail(100)
# Out:
#                     track_name                      track_artist
# 2400                 Fantasies                       Scandium 21
# 2401           Colors of Abuse                       Scandium 21
# 2402             Break of Dawn                       Scandium 21
# 2403                You'll See                       Scandium 21
# 2404          Buy Some Rockets                       Scandium 21
# ...                        ...                               ...
# 2495  Destroying Thunderstorms          Giant Ocean Nature Music
# 2496     Soothing Spring Waves          Jackson 3D Oceanic Waves
# 2497  Early Morning Forest Day           Watery Leaves 8D Sounds
# 2498               Ocean Power      Ocean Downpour Music Library
# 2499       Lazy New York Waves  Sams Dancing Waves Music Project
#
# [100 rows x 2 columns]

# %%
merge_data.shape

# %%
merge_data.to_csv("nothotsongs.csv", index=False)
